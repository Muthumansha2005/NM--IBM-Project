# %% [markdown]
# <a href="https://colab.research.google.com/github/Muthumansha2005/NM--IBM-Project/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv('/content/Housing (2).csv')
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
print(df.describe())
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
x=df[[  'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'furnishingstatus']]
y=df['price']

# %%
df.shape
# Out:
# (545, 13)

# %%
from sklearn.preprocessing import LabelEncoder

df['mainroad'] = LabelEncoder().fit_transform(df['mainroad'])
df['guestroom'] = LabelEncoder().fit_transform(df['guestroom'])
df['basement'] = LabelEncoder().fit_transform(df['basement'])
df['hotwaterheating'] = LabelEncoder().fit_transform(df['hotwaterheating'])
df['airconditioning'] = LabelEncoder().fit_transform(df['airconditioning'])
df['prefarea'] = LabelEncoder().fit_transform(df['prefarea'])
df['furnishingstatus'] = LabelEncoder().fit_transform(df['furnishingstatus'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("original answer",y_test)
# Out:
# original answer 239    4585000
# 113    6083000
# 325    4007500
# 66     6930000
# 479    2940000
#         ...
# 76     6650000
# 132    5810000
# 311    4123000
# 464    3080000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %%
print("ai answer",y_pred)
# Out:
# ai answer [ 4019080.69890147  6258021.768564    4392719.13411047  7335082.21688194
#   2892857.56615675  7084655.57701774  3258634.73504731  3196499.16068631
#   3520106.01134941  8359610.28845465  6646926.36096856  3788844.63269237
#   3734072.96467981  4616010.40973202  3946124.94405792  2023177.4684687
#   3975554.48783028  3624716.9650089   3210282.74216168  4668411.38105794
#   5893719.66376515  6415683.83807236  4657036.55831934  2704096.11205267
#   5356909.86181449  5740682.56798041  5337586.47961082  5444859.96648234
#   5702144.57144375  5865872.30432732  3307327.30668416  6299491.02684292
#   7123479.95544321  2960326.86653052  4424323.19483818  5125081.85591294
#   4947693.93115736  3629027.81981122  2975421.52734786  3975089.54021919
#   8106313.95534003  5014658.87529549  6469749.69804857  3566139.31348661
#   3868652.86219465  6344993.74699856  4482572.73153154  2740240.0896807
#   4105384.15298296  6518557.36176521  3976558.93952635  7056307.68945588
# ...

# %%
from sklearn.metrics import r2_score
a=r2_score(y_test,y_pred)
print("mark",a)
# Out:
# mark 0.6578047592637595

# %%
area = float(input("Enter area (sqft): "))
bedrooms = int(input("Number of bedrooms: "))
bathrooms = int(input("Number of bathrooms: "))
stories = int(input("Number of stories: "))
mainroad = int(input("Mainroad (0 = No, 1 = Yes): "))
guestroom = int(input("Guestroom (0 = No, 1 = Yes): "))
basement = int(input("Basement (0 = No, 1 = Yes): "))
hotwaterheating = int(input("Hot water heating (0 = No, 1 = Yes): "))
airconditioning = int(input("Airconditioning (0 = No, 1 = Yes): "))
parking = int(input("Parking spaces: "))
prefarea = int(input("Preferred area (0 = No, 1 = Yes): "))
furnishingstatus = int(input("Furnishing status (0 = Unfurnished, 1 = Semi-furnished, 2 = Furnished): "))
# Build DataFrame with the same column names and order as training
new_data = pd.DataFrame([[area, bedrooms, bathrooms, stories, mainroad,
                          guestroom, basement, hotwaterheating, airconditioning,
                          parking, prefarea, furnishingstatus]],
                        columns=['area','bedrooms','bathrooms','stories','mainroad',
                                 'guestroom','basement','hotwaterheating','airconditioning',
                                 'parking','prefarea','furnishingstatus'])

# Make prediction
prediction = model.predict(new_data)
print("Predicted house price:", prediction[0])
# Out:
# Enter area (sqft): 2500
# Number of bedrooms: 3
# Number of bathrooms: 2
# Number of stories: 2
# Mainroad (0 = No, 1 = Yes): 1
# Guestroom (0 = No, 1 = Yes): 0
# Basement (0 = No, 1 = Yes): 0
# Hot water heating (0 = No, 1 = Yes): 1
# Airconditioning (0 = No, 1 = Yes): 1
# Parking spaces: 1
# Preferred area (0 = No, 1 = Yes): 2
# Furnishing status (0 = Unfurnished, 1 = Semi-furnished, 2 = Furnished): 2
# Predicted house price: 7586666.971944186
